# %% [markdown]
# # Whisperを試してみる
#
# 実行環境はwhisper_envにする
# なお，pythonのバージョンが3.11.5にした．3.13.2だとまだ対応パッケージがなかった．

# %% [markdown]
# ## まずはFFmpegをインストール
# こいつは仮想環境ではなくシステムにインストールされる

# %%
! brew install ffmpeg
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# ad                         havener                    ratarmount
# adapterremoval             hcledit                    reuse
# aqua                       hk                         rink
# arelo                      hl                         rustywind
# bacon-ls                   identme                    sby
# bagels                     jsrepo                     sitefetch
# bazel@7                    jupytext                   snowflake-cli
# cfnctl                     keeper-commander           soft-serve
# code2prompt                koji                       sql-formatter
# comrak                     lazyjj                     symfony-cli
# ...

# %%
# !pip uninstall numpy -y
# !pip uninstall torch -y
# !pip uninstall torchvision -y
# !pip uninstall torchaudio -y
# !pip uninstall Whisper-openai -y
# Out:
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Successfully uninstalled numpy-1.24.3
# Found existing installation: torch 2.2.2
# Uninstalling torch-2.2.2:
#   Successfully uninstalled torch-2.2.2
# Found existing installation: torchvision 0.17.2
# Uninstalling torchvision-0.17.2:
#   Successfully uninstalled torchvision-0.17.2
# Found existing installation: torchaudio 2.2.2
# Uninstalling torchaudio-2.2.2:
#   Successfully uninstalled torchaudio-2.2.2
# Found existing installation: whisper-openai 1.0.0
# Uninstalling whisper-openai-1.0.0:
#   Successfully uninstalled whisper-openai-1.0.0
# WARNING: Skipping opean-whisper as it is not installed.

# %%
# !pip install numpy==1.24.3
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cpu
# !pip install -U Whisper-openai
# Out:
# ...
#   Using cached numpy-1.24.3-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai-whisper 20240930 requires torch, which is not installed.
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/fujinohidenori/dev/project/.whisper_env/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# ...

# %%
import time
import whisper

input_file = "test.m4a"  # 音声データのファイルパス
model = whisper.load_model("medium")  # 使用するモデルを指定する

start_time = time.time()
result = model.transcribe(input_file, fp16=False)  # 音声データの文字起こし
end_time = time.time()
print(result["text"])  # 文字起こし結果の表示
print(f'実行時間: {end_time - start_time} seconds')
# Out:
